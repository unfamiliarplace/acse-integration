# %% [markdown]
# <a href="https://colab.research.google.com/github/coding-integration/Data_Science/blob/main/DataScience1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcoding-integration%2FData_Science&branch=main&subPath=DataScience1.ipynb&depth=1"  target="_parent"><img src="https://raw.githubusercontent.com/callysto/curriculum-notebooks/master/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"></a>

# %% [markdown]
# # Data Science Part 1
# ### Grade 11 Computer Science, University Preparation (ICS3U1)
#
# # Overall Course Description
# > Students will design software independently and as part of a team, using industry-standard programming tools and applying the software development life-cycle model. They will also write and use subprograms within computer programs.
#
# [source : Ontario Curriculum (2008)](https://www.edu.gov.on.ca/eng/curriculum/secondary/computer10to12_2008.pdf#page=41)

# %% [markdown]
# #Agenda
# *   Introduction to Jupyter notebook using **Python** on *Google Colab* and *Callysto*
# *   Exploring Python data structures, such as lists, sets, dictionaries
# *    Plotting data using **Matplotlib**
# *   Importing a simple dataset of single variable data using Pandas

# %% [markdown]
# ## Learning Goals
# Demonstrate the ability to use different data types, including one-dimensional arrays (lists), in computer programs;

# %% [markdown]
# ## Sucess Criteria
# *   I can use the most appropriate data type to design, implement, and test Python programs.
# *   I can demonstrate how data is encoded and stored using various systems including binary, hexadecimal, and UNICODE.

# %% [markdown]
# Data is **encoded** using many different techniques. Images are encoded using pixels and colors. Text is encoded using [Unicode](https://home.unicode.org/).
#
# Here we will use the power of Jupyter notebooks and Python to actually see some of the printable characters defined within the Unicode standard.
#
# Let's start with the standard numbers and letters.

# %%
print (f"DEC   HEX        BIN   VALUE")
for a in range(65,123,1):
  print (f'{a:3}    {a:x}   {a:08b}       {chr(a)}')
# Out:
# DEC   HEX        BIN   VALUE
#  65    41   01000001       A
#  66    42   01000010       B
#  67    43   01000011       C
#  68    44   01000100       D
#  69    45   01000101       E
#  70    46   01000110       F
#  71    47   01000111       G
#  72    48   01001000       H
#  73    49   01001001       I
#  74    4a   01001010       J
#  75    4b   01001011       K
#  76    4c   01001100       L
#  77    4d   01001101       M
#  78    4e   01001110       N
#  79    4f   01001111       O
#  80    50   01010000       P
#  81    51   01010001       Q
#  82    52   01010010       R
#  83    53   01010011       S
#  84    54   01010100       T
#  85    55   01010101       U
#  86    56   01010110       V
#  87    57   01010111       W
#  88    58   01011000       X
#  89    59   01011001       Y
#  90    5a   01011010       Z
#  91    5b   01011011       [
#  92    5c   01011100       \
#  93    5d   01011101       ]
#  94    5e   01011110       ^
#  95    5f   01011111       _
# ...

# %% [markdown]
# Now let's explore much larger values. We will start with the famous [smiley face emoji](https://unicode-table.com/en/1F600/) which is defined using the hexadecimal Unicode value of **`x1f600`** or decimal 128512.

# %%
# Emojis are encoded using the same technique as letters and numbers

print (f"   DEC      HEX                 BIN    VALUE")
for a in range(128512,128592,1):
  print (f'{a:3}    {a:x}   {a:8b}       {chr(a)}')
# Out:
#    DEC      HEX                 BIN    VALUE
# 128512    1f600   11111011000000000       😀
# 128513    1f601   11111011000000001       😁
# 128514    1f602   11111011000000010       😂
# 128515    1f603   11111011000000011       😃
# 128516    1f604   11111011000000100       😄
# 128517    1f605   11111011000000101       😅
# 128518    1f606   11111011000000110       😆
# 128519    1f607   11111011000000111       😇
# 128520    1f608   11111011000001000       😈
# 128521    1f609   11111011000001001       😉
# 128522    1f60a   11111011000001010       😊
# 128523    1f60b   11111011000001011       😋
# 128524    1f60c   11111011000001100       😌
# 128525    1f60d   11111011000001101       😍
# 128526    1f60e   11111011000001110       😎
# 128527    1f60f   11111011000001111       😏
# 128528    1f610   11111011000010000       😐
# 128529    1f611   11111011000010001       😑
# 128530    1f612   11111011000010010       😒
# 128531    1f613   11111011000010011       😓
# ...

# %% [markdown]
# There are many **datatypes** used in Python. For this notebook we will primarily be working with numeric data including integers and float values.
#
# *   integer - whole numbers
# *   float - numbers with decimal components
# *   string - a series of characters

# %% [markdown]
# Examples of integers could be: **`-23, 0, 22`**
#
# ---
#
#
#
# Let's assign some values to variables and perform math operations using the data.
#
#
#
# ---
#
#
# NOTES:
#
# Some programming languages require the programmer to *explicitly* state the data type when the variable is introduced.
#
# Python is a *dynamically typed language* and therefore it will attempt to determine the data type based on the context of how it is used.

# %% [markdown]
# Let's work with some **eggs** for this task. We will create a variable that will be used to track the total number of eggs.
#
# A **variable** is simply a *named storage area* within a programming language.

# %% [markdown]
# ![8610203218_5f3ef01ba9_w.jpg](data:image/jpeg;base64,...)

# %%
eggs = 20

# %% [markdown]
# Let's verify the datatype of this new variable.
#
# We can use the built-in **`type()`** function to perform this task.

# %%
type (eggs)
# Out:
# int

# %% [markdown]
# Now let's verify that we can perform typical math operations using this variable.
#
#
# ---
#
#
# **NOTE:**
#
# The math operation for multiplication is the asterisk **`*`** and not the **`x`** symbol.
#
#
# ---
#
#
# Let's double the number of eggs.

# %%
eggs * 2
# Out:
# 40

# %% [markdown]
# **STUDENT CHALLENGE**: Write a Python statement to triple the number of eggs.

# %%
# write a math statement to triple the number of eggs
# Out:
# 60

# %% [markdown]
# Let's verify that the data type remains the same when we multiply by another integer value.

# %%
type (eggs * 2)
# Out:
# int

# %% [markdown]
# **STUDENT CHALLENGE:** Write a Python statement to determine the number of addition eggs if you increased the amount by 40%.

# %%
# write a math statement to determine 40% of the current number of eggs

# %% [markdown]
# **CHALLENGE:** Verify the data type of the result of the previous math operation.

# %%
# verify the data type of the result of the math expression

# %% [markdown]
# We have now encounterred our first example of a **float** variable. When a math operation is performed with at least one of the variables or numbers that contain a decimal the output will be of type **float**.
#
# In this case, 8 eggs would represent 40% of the original amount so let's add this to the original amount and store it in a new variable called **`total_eggs`**.

# %%
total_eggs = eggs + eggs * .40

# %% [markdown]
# We can use the built-in **`print()`** function to check the current value stored in each variable.

# %%
print (eggs)
print (total_eggs)
# Out:
# 20
# 28.0

# %% [markdown]
# Notice how the total_eggs variable includes a decimal component as it is stored as a float variable and not an integer. In this case it doesn't matter too much.
#
# What would happen if the percentage increase resulted in a number with a non-zero fractional component?
#
# ---
# **CHALLENGE:** Determine the number of eggs for a 57% increase

# %%
# Write a statement to determine 55% of the original number of eggs - stored in eggs variable
eggs * .57
# Out:
# 11.399999999999999

# %% [markdown]
# Notice how Python was not able to determine a specific answer. The approximate result is 11.4 eggs.
#
# If we are targetting egg production of 57% or more we would need to increase the original number of eggs by 12. Therefore we are looking to round up the answer to the next highest whole number. This can be accomplished using a built-in function called **`math.ceil()`**.
#
# NOTE: The function `ceil()` is short for ceiling.
#
# To use this function we must import the math library as shown.

# %%
import math
math.ceil(eggs * .57)

# %% [markdown]
# The **modulus** operator `%` is very useful as it can be used to determine the remainder following a division operation.
#
# Let's consider the problem of determining the number of egg cartons required for a quantity of eggs.

# %%
eggs = 129       # total number of eggs to be transported
carton_size = 12 # each carton can hold a dozen eggs

# %% [markdown]
# We now have our 2 data items stored. Let's use Python to determine the number of required cartons.

# %%
# Determine the number of cartons needed
num_cartons = eggs / carton_size
print (num_cartons)
# Out:
# 10.75

# %% [markdown]
# According to the result we would need 11 cartons. This could be computed precisely using the `math.ceil()` function.

# %%
import math
num_cartons = math.ceil(eggs / carton_size)
print (num_cartons)
# Out:
# 11

# %% [markdown]
# How could we determine how full the partial container is?

# %% [markdown]
# **STUDENT CHALLENGE:**
#
# How many eggs are in the partially full container?

# %%
# Use the modulo operator to determine the number of eggs in the last container
remaining = eggs % carton_size
print (remaining)
# Out:
# 9

# %% [markdown]
# # Python Data Structures
#
# * lists
# * dictionaries
# * sets
#
#
# All of these 3 data structures are dynamic as they can grow and shrink as needed.
#
#
# ---
#
#
#
# *   List items are usually accessed by their position or **index**.
# *   Set items are not ordered and they cannot contain duplicate values.
# *   Dictionary items are accessed by their **key** value.
#    *   A key is a unique piece of information that can be used to locate corresponding value or values.

# %% [markdown]
# ## Python Lists
#
# Let's start with a simple set of grades for a class. We will assume that these grades are whole numbers.
#
# For this exercise we will also explore how to obtain user input from a Jupyter notebook.
#
# We would like the program to be flexible so we will ask the user for the number of courses and we will then store the grades in a list called **`grades`**.

# %% [markdown]
# Algorithms are usually described using **pseudocode**.
#
# Let's examine pseudocode for an algorithm to determine the range of a list of values.

# %% [markdown]
# **PSEUDOCODE**
#
# ```
# Ask user for the number of grades - num_grades
# Create a list called grades to store values
# Repeat num_grades times
#    Obtain grade from user
#    Add the grade to the end of the list
# ```

# %%
# Code to populate list of grades
grades = [] # define list data structure

num_grades = int(input("How many grades? "))

for i in range(num_grades):
  grades.append(int(input("Grade: ")))
# Out:
# How many grades? 5
# Grade: 80
# Grade: 87
# Grade: 90
# Grade: 67
# Grade: 99

# %% [markdown]
# Let's verify the number of grades in our list we can use the built-in **`len(<list>)`** function.
#
# ---
#
#
# Note:
#
# The `len()` function can be used for any of our data structures.

# %%
num_items = len(grades)

# Example of using an f-string in Python to embed variables in a string for formatted output.
print (f'There are {num_items} grades stored in the list')
# Out:
# There are 5 grades stored in the list

# %% [markdown]
# # Single-Variable Data Analysis
#
# Let's explore some of the most common single-variable data analysis techniques using Python.
#
#
# We will start with a first principals approach using explicit algorithms involving loops and conditionals.
#
# In this notebook we will use Python libraries such as **Matplotlib** and others (Numpy / Pandas).

# %% [markdown]
# We will examine the following:
#
#
# *   `range`
# *   `mean (arithmetic average)`
# *   `median`

# %% [markdown]
# ## Calculating Range

# %% [markdown]
# The range measures the spread of data values. We would need to find the smallest and largest value in the list and calculate the difference.
#
# In Python, this can be accomplished easily as there are built-in functions that we can use.
#
# * [**`max(list)`**](https://docs.python.org/3/library/functions.html#max)
# * [**`min(list)`**](https://docs.python.org/3/library/functions.html#min)

# %%
# Determine the range of values
data_range = max(grades) - min(grades)
print (data_range)
# Out:
# 32

# %% [markdown]
# Many programming languages do not have these built in functions so it is important to understand how to use repetition statements (loops) and conditionals to implement the algorithms.

# %% [markdown]
# **PSEUDOCODE**
#
# ```
# Set the lowest_grade to the first item in the list
# Set the highest_grade to the first item in the list
#
# Repeat for each grade in the list
#     if the current_grade is greater than the highest_grade
#         set the highest_grade to the current_grade
#
#     if the current_grade is less than the lowest_grade
#         set the lowest_grade to the current_grade
#
# range = highest_grade - lowest_grade
# Display the range
# ```

# %% [markdown]
# We have converted the pseudocode to Python below.
#
# Read the code to verify it matches the pseudocode.

# %%
lowest_grade = grades[0]
highest_grade = grades[0]

for current_grade in grades:
  if current_grade > highest_grade:
    highest_grade = current_grade
  elif current_grade < lowest_grade:
    lowest_grade = current_grade

data_range = highest_grade - lowest_grade
print (data_range)
# Out:
# 32

# %% [markdown]
# **STUDENT CHALLENGE:**
#
# How would the range change if the lowest and highest values were removed?
#
# To verify your answer **design** and **implement** an **algorithm** to test your answer.
#
# You may want to research the following topics:
#
# *   How to copy a list to a new list?
# *   How do I remove items from a list by value?

# %% [markdown]
# **PSEUDOCODE**
# ```
# TODO
# ```

# %%
# Code to copy list and remove the lowest and highest items

# %%
new_grades = grades[:]
new_grades.remove(highest_grade)
new_grades.remove(lowest_grade)

# %% [markdown]
# Since we have written the algorithm for calculating the range of values let's go ahead and create a reusable coding artifact or **function**.
#
# In Python functions are created using the **`def`** keyword. Each function can include input parameters and return values.
#
# In this case our input will be **a list of numeric values** and our return value will be a number. Due to the dynamic data typing of Python the function will be able to handle integer or float values.
#
#
# ---
#
#
# NOTE: We will avoid using the function name of **range()** as it is a built-in keyword that is used in Python frequently.

# %%
def find_range(data):
  """Calculates the range of data values

  Parameters:
  data : (list of numbers)

  Returns:
  number: Returns a number of the same data type provided in data
  """
  return max(data)-min(data)

# %% [markdown]
# Now that the `find_range()` function has been defined we can use it on the new list that we created with the lowest and highest grades removed.

# %%
print(find_range(new_grades))
# Out:
# 10

# %% [markdown]
# Let's print the contents of both lists to be sure that the 2 items have been removed properly.

# %%
print (grades)
print (new_grades)
# Out:
# [80, 87, 90, 67, 99]
# [80, 87, 90]

# %% [markdown]
# Python lists do not maintain the items in a sorted order. If you would like to sort the data there are 2 techniques typically used.
#
# *   Sort the items within the existing list (in-place sort).
# *   Create a new list that is in sorted order.
#
# Sorting is explained in the Python [documentation](https://docs.python.org/3/howto/sorting.html) .
#
# *  If we would like to sort the data **in-place** simply use the `<list>.sort()` method.
#
# *  To **create a new sorted list** use the `sorted(<list>) -> new_list` function.

# %%
sorted_grades = sorted(new_grades)
print (sorted_grades)
# Out:
# [80, 87, 90]

# %%
print (new_grades)
# Out:
# [80, 87, 90]

# %%
new_grades.sort()
print (new_grades)
# Out:
# [80, 87, 90]

# %% [markdown]
# ## Calculating Mean - Arithmetic Average

# %% [markdown]
# The mean or arithmetic average is the ratio of the sum of the data values and
# the number of values.
#
# The mean can be computed using the following built-in function:
# * [**`sum()`**](https://docs.python.org/3/library/functions.html#sum)
# * [**`len()`**](https://docs.python.org/3/library/functions.html#len)
#
# Let's practice creating new functions.

# %% [markdown]
# **STUDENT CHALLENGE:**
#
# Create a function called **`mean(<list>)->float`**

# %%
def mean(data):
  return sum(data)/len(data)

# %% [markdown]
# Now let's use the new function to find the mean of the original list of grades.

# %%
mean(grades)
# Out:
# 84.6

# %% [markdown]
# What was the impact of removing the lowest and highest grades?

# %%
mean(new_grades)
# Out:
# 85.66666666666667

# %% [markdown]
# You may want to explore the built-in [**`round()`**](https://docs.python.org/3/library/functions.html#round) function in Python to round the result to the nearest whole number of to any number of decimals.

# %%
round(mean(new_grades),2)
# Out:
# 85.67

# %% [markdown]
# ## Calculating Median
#
# The median is another measure of central tendancy for data, but unlike mean it is not skewed by very small or large values.
#
# The median is the middle item in a sorted list of data. If there are an even number of items in the list the median is the mean of the 2 middle items.

# %% [markdown]
# **STUDENT CHALLENGE:**
#
# Design and implement a median function that can handle numeric lists of varying lengths.

# %% [markdown]
# **PSEUDOCODE**
# ```
# TODO
# ```

# %%
def median(data):
  # create a sorted version of the data
  new_data = sorted(data)

  # return the middle item if there is an odd number of items
  if (len(new_data)%2==1):
    return new_data[len(new_data)//2]
  
  # find the sum of the 2 middle items
  sum_middle = new_data[len(new_data)//2] + new_data[len(new_data)//2+1]

  # calculate and return the mean or arithmetic average of the 2 middle_items
  return sum_middle/2.0

# %%
median(grades)
# Out:
# 87

# %%
median(new_grades)
# Out:
# 87

# %% [markdown]
# # Data Visualization

# %% [markdown]
# There are many techniques available to [visualize data](https://www150.statcan.gc.ca/n1/edu/power-pouvoir/ch9/5214821-eng.htm).
#
# For single-variable data analysis some of the most common representations include:
#
#
# *   histograms
# *   boxplots
# *   pie charts

# %% [markdown]
# ## Histogram
# A **histogram** is used to display the distribution of data within a dataset. The data is grouped based on bins.
#
# The data set itself is not changed in any way.
#
# Examine the code below to explore how a random set of data.
#
# We are using the **[matplotlib](https://matplotlib.org/)** library to accomplish this simple visualization.

# %%
import matplotlib.pyplot as plt
import random
import numpy as np

large_data = []
for _ in range(120):
  large_data.append(random.randint(50, 100))

# alternate technique to generate random data using numpy library
# large_data = np.random.randint(50,100,120)

plt.hist(large_data, bins=[0,50,60,70,80,90,100],rwidth=0.9, edgecolor='black')
plt.xlabel("Grades")
plt.xticks(np.arange(0,101,10))

plt.show()

# %% [markdown]
# ## Boxplot
#
# Earlier we calculated the mean and median of a list of grades. Let's explore the distribution of grades using a boxplot.
#
# A **boxplot** will show the median, 25th percentile, 75% percentile, and the extreme values of a set of data.
#
#
# ---

# %%
# Creating plot
plt.boxplot(large_data)
 
# show plot
plt.show()

# %% [markdown]
# ## Dictionaries
#
# Let's work on an algorithm to determine the frequency distribution of the data in our large_data list.
#
# We will create a Python dictionary where the key is the Level (1,2,3,4) and we will use the following rules:
#
#
# *   Level 1 grades fall between 50 and 59 (inclusive)
# *   Level 2 grades fall between 60 and 69 (inclusive)
# *   Level 3 grades fall between 70 and 79 (inclusive)
# *   Level 4 grades fall between 80 and 100 (inclusive)
#
# Python dictionaries use Keys and Values.

# %%
# create dictionary to hold the frequency of levels
levels = {}

for grade in large_data:
  if (grade >=50 and grade <60):
    if (levels.get('1') == None):
      levels['1'] =1
    else:
      levels['1'] += 1
  elif (grade >=60 and grade <70):
    if (levels.get('2') == None):
      levels['2'] =1
    else:
      levels['2'] += 1
  elif (grade >=70 and grade <80):
    if (levels.get('3') == None):
      levels['3'] =1
    else:
      levels['3'] +=1
  elif (grade >=80):
    if (levels.get('4') == None):
      levels['4'] =1
    else:
      levels['4'] += 1

print (levels)
# Out:
# {'4': 51, '3': 27, '2': 21, '1': 21}

# %% [markdown]
# The code shown above creates a dictionary data structure and if the key does not have a value (`None`) then a 1 is stored as the first occurence of a grade at the level. If the key has an associated value then the value is increased by 1.
#
# At the end of this loop we have a set of keys with corresponding counts representing the frequency of the values.

# %% [markdown]
# ## Pie Chart - Circle Chart
#
# A **pie chart** is a useful visualization to see the distribution of data as a percentage. The area of each segment represents the proportion of the data within the category.

# %% [markdown]
# In the code shown below we are able to extract the keys using the Python `keys()` method for dictionaries and the values are extracted using the `values()` method.

# %%
keys = levels.keys()
values = levels.values()

plt.pie(values, labels=keys)
plt.title("Distribution of Grades")
plt.show()

# %% [markdown]
# # Importing Data
#
# For this notebook we will explore some simple datasets.
#
# We will start with a text file containing the words used in a collection of beatles songs.

# %%
import pandas as pd

df = pd.read_csv('beatles.dat',header=None)

print (df.shape) # number of words
# Out:
# (47623, 1)

# %% [markdown]
# The dataframe consists of 47623 rows and a single column.

# %% [markdown]
# Let's determine the number of unique words in the lyrics.
#
# We will create a Python set of words, but to do this we will first extract the words into a Python list.

# %%
words = df[df.columns[0]].values.tolist() # convert column index 0 to a create a list

print (words)
# Out:
# ['words', 'are', 'flowing', 'out', 'like', 'endless', 'rain', 'into', 'a', 'paper', 'cup', 'they', 'slither', 'while', 'they', 'pass', 'they', 'slip', 'away', 'across', 'the', 'universe', 'pools', 'of', 'sorrow', 'waves', 'of', 'joy', 'are', 'drifting', 'through', 'my', 'opened', 'mind', 'possessing', 'and', 'caressing', 'me', 'jai', 'guru', 'deva', 'om', 'nothings', 'gonna', 'change', 'my', 'world', 'nothings', 'gonna', 'change', 'my', 'world', 'nothings', 'gonna', 'change', 'my', 'world', 'nothings', 'gonna', 'change', 'my', 'world', 'images', 'of', 'broken', 'light', 'which', 'dance', 'before', 'me', 'like', 'a', 'million', 'eyes', 'they', 'call', 'me', 'on', 'and', 'on', 'across', 'the', 'universe', 'thoughts', 'meander', 'like', 'a', 'restless', 'wind', 'inside', 'a', 'letter', 'box', 'they', 'stumble', 'blindly', 'as', 'they', 'make', 'their', 'way', 'across', 'the', 'universe', 'jai', 'guru', 'deva', 'om', 'nothings', 'gonna', 'change', 'my', 'world', 'nothings', 'gonna', 'cha
# ...

# %% [markdown]
# # Sets
#
# A Python set is an unordered data structure that does not allow for duplicate values.
#
# Let's iterate over the word list and populate a set of unique words.

# %%
unique_words = set()

for word in words:
  unique_words.add(word)

print (len(unique_words))
# Out:
# 2976

# %% [markdown]
# We now know the set of unique words from the larger list.
#
# Let's determine the frequency of each of the word using a similar technique that we used to determine the levels for the grades from before.
#
# We will define a dictionary where the **key is the word** and the **value will be the count** or frequency of the word.

# %%
word_freq = {}

for word in words:
  if (word_freq.get(word) == None):
    word_freq[word] = 1
  else:
    word_freq[word] += 1

print (word_freq)
# Out:
# {'words': 25, 'are': 94, 'flowing': 2, 'out': 122, 'like': 194, 'endless': 1, 'rain': 23, 'into': 21, 'a': 858, 'paper': 6, 'cup': 5, 'they': 99, 'slither': 1, 'while': 26, 'pass': 14, 'slip': 3, 'away': 88, 'across': 16, 'the': 1355, 'universe': 5, 'pools': 1, 'of': 369, 'sorrow': 6, 'waves': 4, 'joy': 12, 'drifting': 1, 'through': 51, 'my': 610, 'opened': 3, 'mind': 73, 'possessing': 1, 'and': 962, 'caressing': 1, 'me': 1059, 'jai': 7, 'guru': 7, 'deva': 7, 'om': 3, 'nothings': 12, 'gonna': 164, 'change': 41, 'world': 58, 'images': 1, 'broken': 11, 'light': 14, 'which': 8, 'dance': 81, 'before': 48, 'million': 5, 'eyes': 52, 'call': 48, 'on': 368, 'thoughts': 1, 'meander': 1, 'restless': 1, 'wind': 10, 'inside': 23, 'letter': 12, 'box': 1, 'stumble': 1, 'blindly': 1, 'as': 102, 'make': 116, 'their': 27, 'way': 144, 'sounds': 1, 'laughter': 2, 'shades': 1, 'life': 58, 'ringing': 3, 'open': 10, 'inciting': 1, 'inviting': 1, 'limitless': 1, 'undying': 1, 'love': 613, 'shines': 7, 'aro
# ...

# %% [markdown]
# It is a bit of a challenge to determine the most frequent words.
#
# In the code below we create a new list that is sorted in reverse order based on the counts.

# %%
# create list of the most frequent words sorted by count
most_freq = []
for key in word_freq.keys():
  most_freq.append([word_freq[key],key])

sorted_freq = sorted (most_freq,reverse=True)

for i in range(10):
  print (sorted_freq[i])
# Out:
# [2261, 'you']
# [1734, 'i']
# [1355, 'the']
# [1097, 'to']
# [1059, 'me']
# [962, 'and']
# [858, 'a']
# [613, 'love']
# [610, 'my']
# [513, 'in']

# %% [markdown]
# We will conclude our analysis at this point.
